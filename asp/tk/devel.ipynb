# %%
# %%clingo --time-limit=10 --opt-mode=optN tracks.lp encoding.lp env_001--1_6.lp -
#
# #show action_space/3.
# Out:
# clingo version 5.8.0
# Reading from tracks.lp ...
# Solving...
# Answer: 1 (Time: 0.122s)
# action_space((4,20),wait,w) action_space((7,21),wait,w) action_space((16,23),wait,w) action_space((19,24),wait,w) action_space((4,20),wait,s) action_space((7,21),wait,s) action_space((16,23),wait,s) action_space((19,24),wait,s) action_space((4,7),wait,e) action_space((7,20),wait,e) action_space((9,7),wait,e) action_space((16,6),wait,e) action_space((19,23),wait,e) action_space((21,6),wait,e) action_space((4,7),wait,s) action_space((7,20),wait,s) action_space((9,7),wait,s) action_space((16,6),wait,s) action_space((19,23),wait,s) action_space((21,6),wait,s) action_space((3,21),wait,e) action_space((15,24),wait,e) action_space((2,20),wait,s) action_space((3,6),wait,s) action_space((3,7),wait,s) action_space((6,20),wait,s) action_space((6,21),wait,s) action_space((8,6),wait,s) action_space((8,7),wait,s) action_space((10,20),wait,s) action_space((12,23),wait,s) action_space((13,6),wait,s) action_space((14,23),wait,s) action_space((15,5),wait,s) action_space((15,6),wait,s) action_space((18,23),wait,s) action_space((18,24),wait,s) action_space((20,5),wait,s) action_space((20,6),wait,s) action_space((22,23),wait,s) action_space((23,6),wait,s) action_space((1,13),wait,w) action_space((23,10),wait,w) action_space((3,20),wait,s) action_space((4,6),wait,s) action_space((8,20),wait,s) action_space((9,6),wait,s) action_space((15,23),wait,s) action_space((16,5),wait,s) action_space((20,23),wait,s) action_space((21,5),wait,s) action_space((4,21),wait,s) action_space((16,24),wait,s) action_space((1,14),wait,e) action_space((2,12),wait,e) action_space((13,22),wait,e) action_space((23,11),wait,e) action_space((23,22),wait,e) action_space((24,9),wait,e) action_space((24,11),wait,e) action_space((2,6),wait,n) action_space((5,19),wait,n) action_space((14,5),wait,n) action_space((17,22),wait,n) action_space((7,19),wait,s) action_space((19,22),wait,s) action_space((24,5),wait,s) action_space((4,20),wait,n) action_space((5,6),wait,n) action_space((9,20),wait,n) action_space((10,6),wait,n) action_space((16,23),wait,n) action_space((17,5),wait,n) action_space((21,23),wait,n) action_space((22,5),wait,n) action_space((8,21),wait,n) action_space((20,24),wait,n) action_space((3,7),wait,n) action_space((6,6),wait,n) action_space((6,7),wait,n) action_space((6,20),wait,n) action_space((6,21),wait,n) action_space((10,20),wait,n) action_space((11,6),wait,n) action_space((11,7),wait,n) action_space((14,23),wait,n) action_space((15,6),wait,n) action_space((18,5),wait,n) action_space((18,6),wait,n) action_space((18,23),wait,n) action_space((18,24),wait,n) action_space((22,23),wait,n) action_space((23,5),wait,n) action_space((23,6),wait,n) action_space((12,20),wait,w) action_space((2,15),wait,e) action_space((9,21),wait,e) action_space((21,24),wait,e) action_space((24,23),wait,e) action_space((5,21),wait,n) action_space((8,20),wait,n) action_space((17,24),wait,n) action_space((20,23),wait,n) action_space((5,21),wait,w) action_space((8,20),wait,w) action_space((17,24),wait,w) action_space((20,23),wait,w) action_space((5,7),wait,n) action_space((5,20),wait,n) action_space((10,7),wait,n) action_space((17,6),wait,n) action_space((17,23),wait,n) action_space((22,6),wait,n) action_space((5,7),wait,e) action_space((5,20),wait,e) action_space((10,7),wait,e) action_space((17,6),wait,e) action_space((17,23),wait,e) action_space((22,6),wait,e) action_space((3,21),wait,n) action_space((5,22),wait,n) action_space((15,24),wait,n) action_space((17,25),wait,n) action_space((1,16),wait,w) action_space((2,8),wait,w) action_space((2,14),wait,w) action_space((11,21),wait,w) action_space((23,13),wait,w) action_space((24,7),wait,w) action_space((24,11),wait,w) action_space((24,13),wait,w) action_space((7,22),wait,s) action_space((9,21),wait,s) action_space((14,7),wait,s) action_space((19,25),wait,s) action_space((21,24),wait,s) action_space((2,20),move_forward,0) action_space((3,6),move_forward,0) action_space((3,7),move_forward,0) action_space((6,6),move_forward,0) action_space((6,7),mo ...
# SATISFIABLE
#
# Models       : 1+
# Calls        : 1
# Time         : 0.122s (Solving: 0.00s 1st Model: 0.00s Unsat: 0.00s)
# CPU Time     : 0.122s

# %%
from clingo import Control

env_encoding_file = "env_001--1_6.lp"
tracks_file = "tracks.lp"
encoding_file = "encoding.lp"
# ctl = Control(["0"])
ctl = Control()
ctl.load(env_encoding_file)
ctl.load(tracks_file)
ctl.load(encoding_file)
ctl.ground()
grid = {}
with ctl.solve(yield_ = True) as handle:
    for i, model in enumerate(handle):
        print(f"Model #{i}:")
        for symbol in model.symbols(shown = True):
            if symbol.name in ["action"]:
                print(f"  {symbol}")
            if symbol.name == "action_space":
                print(f"  {symbol}")
                # if symbol.arguments[0].arguments:
            #         x = symbol.arguments[0].arguments[0].number
            #         y = symbol.arguments[0].arguments[1].number
            #         if x == 7 and y == 6:
            #             print(f"  action_space at ({x},{y}): {symbol}")
    print(handle.get())
# Out:
# Model #0:
#   action_space((2,20),move_forward,0)
#   action_space((3,6),move_forward,0)
#   action_space((3,7),move_forward,0)
#   action_space((6,6),move_forward,0)
#   action_space((6,7),move_forward,0)
#   action_space((6,19),move_forward,0)
#   action_space((6,20),move_forward,0)
#   action_space((6,21),move_forward,0)
#   action_space((6,22),move_forward,0)
#   action_space((7,6),move_forward,0)
#   action_space((7,7),move_forward,0)
#   action_space((8,6),move_forward,0)
#   action_space((8,7),move_forward,0)
#   action_space((10,20),move_forward,0)
#   action_space((11,6),move_forward,0)
#   action_space((11,7),move_forward,0)
#   action_space((12,6),move_forward,0)
#   action_space((12,7),move_forward,0)
#   action_space((12,23),move_forward,0)
#   action_space((13,6),move_forward,0)
#   action_space((13,7),move_forward,0)
#   action_space((14,23),move_forward,0)
#   action_space((15,5),move_forward,0)
#   action_space((15,6),move_forward,0)
#   action_space((18,5),move_forward,0)
#   action_space((18,6),move_forward,0)
#   action_space((18,22),move_forward,0)
#   action_space((18,23),move_forward,0)
#   action_space((18,24),move_forward,0)
#   action_space((18,25),move_forward,0)
#   action_space((19,5),move_forward,0)
#   action_space((19,6),move_forward,0)
#   action_space((20,5),move_forward,0)
#   action_space((20,6),move_forward,0)
#   action_space((22,23),move_forward,0)
#   action_space((23,5),move_forward,0)
#   action_space((23,6),move_forward,0)
#   action_space((2,20),move_forward,2)
#   action_space((3,6),move_forward,2)
#   action_space((3,7),move_forward,2)
#   action_space((6,6),move_forward,2)
#   action_space((6,7),move_forward,2)
#   action_space((6,19),move_forward,2)
#   action_space((6,20),move_forward,2)
#   action_space((6,21),move_forward,2)
#   action_space((6,22),move_forward,2)
#   action_space((7,6),move_forward,2)
#   action_space((7,7),move_forward,2)
#   action_space((8,6),move_forward,2)
#   action_space((8,7),move_forward,2)
#   action_space((10,20),move_forward,2)
#   action_space((11,6),move_forward,2)
#   action_space((11,7),move_forward,2)
#   action_space((12,6),move_forward,2)
#   action_space((12,7),move_forward,2)
#   action_space((12,23),move_forward,2)
#   action_space((13,6),move_forward,2)
#   action_space((13,7),move_forward,2)
#   action_space((14,23),move_forward,2)
#   action_space((15,5),move_forward,2)
#   action_space((15,6),move_forward,2)
#   action_space((18,5),move_forward,2)
#   action_space((18,6),move_forward,2)
#   action_space((18,22),move_forward,2)
#   action_space((18,23),move_forward,2)
#   action_space((18,24),move_forward,2)
#   action_space((18,25),move_forward,2)
#   action_space((19,5),move_forward,2)
#   action_space((19,6),move_forward,2)
#   action_space((20,5),move_forward,2)
#   action_space((20,6),move_forward,2)
#   action_space((22,23),move_forward,2)
#   action_space((23,5),move_forward,2)
#   action_space((23,6),move_forward,2)
#   action_space((1,20),move_forward,3)
#   action_space((3,21),move_forward,3)
#   action_space((5,22),move_forward,3)
#   action_space((11,23),move_forward,3)
#   action_space((12,21),move_forward,3)
#   action_space((15,24),move_forward,3)
#   action_space((17,25),move_forward,3)
#   action_space((1,20),move_forward,0)
#   action_space((3,21),move_forward,0)
#   action_space((5,22),move_forward,0)
#   action_space((11,23),move_forward,0)
#   action_space((12,21),move_forward,0)
#   action_space((15,24),move_forward,0)
#   action_space((17,25),move_forward,0)
#   action_space((4,7),move_left,0)
#   action_space((7,20),move_left,0)
#   action_space((8,21),move_left,0)
#   action_space((9,7),move_left,0)
#   action_space((13,23),move_left,0)
#   action_space((16,6),move_left,0)
#   action_space((19,23),move_left,0)
#   action_space((20,24),move_left,0)
#   action_space((21,6),move_left,0)
#   action_space((4,7),move_forward,2)
#   action_space((7,20),move_forward,2)
#   action_space((8,21),move_forward,2)
#   action_space((9,7),move_forward,2)
#   action_space((13,23),move_forward,2)
#   action_space((16,6),move_forward,2)
#   action_space((19,23),move_forward,2)
#   action_space((20,24),move_forward,2)
#   action_space((21,6),move_forward,2)
#   action_space((4,7),move_forward,0)
#   action_space((7,20),move_forward,0)
#   action_space((8,21),move_forward,0)
#   action_space((9,7),move_forward,0)
#   action_space((13,23),move_forward,0)
#   action_space((16,6),move_forward,0)
#   action_space((19,23),move_forward,0)
#   action_space((20,24),move_forward,0)
#   action_space((21,6),move_forward,0)
#   action_space((4,7),move_forward,3)
#   action_space((7,20),move_forward,3)
#   action_space((8,21),move_forward,3)
#   action_space((9,7),move_forward,3)
#   action_space((13,23),move_forward,3)
#   action_space((16,6),move_forward,3)
#   action_space((19,23),move_forward,3)
#   action_space((20,24),move_forward,3)
#   action_space((21,6),move_forward,3)
#   action_space((4,20),move_right,0)
#   action_space((5,6),move_right,0)
#   action_space((7,21),move_right,0)
#   action_space((9,20),move_right,0)
#   action_space((10,6),move_right,0)
#   action_space((16,23),move_right,0)
#   action_space((17,5),move_right,0)
#   action_space((19,24),move_right,0)
#   action_space((21,23),move_right,0)
#   action_space((22,5),move_right,0)
#   action_space((4,20),move_forward,2)
#   action_space((5,6),move_forward,2)
#   action_space((7,21),move_forward,2)
#   action_space((9,20),move_forward,2)
#   action_space((10,6),move_forward,2)
#   action_space((16,23),move_forward,2)
#   action_space((17,5),move_forward,2)
#   action_space((19,24),move_forward,2)
#   action_space((21,23),move_forward,2)
#   action_space((22,5),move_forward,2)
#   action_space((4,20),move_forward,1)
#   action_space((5,6),move_forward,1)
#   action_space((7,21),move_forward,1)
#   action_space((9,20),move_forward,1)
#   action_space((10,6),move_forward,1)
#   action_space((16,23),move_forward,1)
#   action_space((17,5),move_forward,1)
#   action_space((19,24),move_forward,1)
#   action_space((21,23),move_forward,1)
#   action_space((22,5),move_forward,1)
#   action_space((4,20),move_forward,0)
#   action_space((5,6),move_forward,0)
#   action_space((7,21),move_forward,0)
#   action_space((9,20),move_forward,0)
#   action_space((10,6),move_forward,0)
#   action_space((16,23),move_forward,0)
#   action_space((17,5),move_forward,0)
#   action_space((19,24),move_forward,0)
#   action_space((21,23),move_forward,0)
#   action_space((22,5),move_forward,0)
#   action_space((14,6),move_left,0)
#   action_space((14,6),move_right,3)
#   action_space((14,6),move_right,1)
#   action_space((14,6),move_left,2)
#   action_space((14,6),move_forward,0)
#   action_space((14,6),move_forward,1)
#   action_space((14,6),move_forward,2)
#   action_space((14,6),move_forward,3)
#   action_space((14,6),move_forward,e)
#   action_space((14,6),move_forward,s)
#   action_space((14,6),move_forward,w)
#   action_space((14,6),move_forward,n)
#   action_space((14,6),move_left,s)
#   action_space((14,6),move_right,w)
#   action_space((14,6),move_right,e)
#   action_space((14,6),move_left,n)
#   action_space((4,20),move_forward,n)
#   action_space((5,6),move_forward,n)
#   action_space((7,21),move_forward,n)
#   action_space((9,20),move_forward,n)
#   action_space((10,6),move_forward,n)
#   action_space((16,23),move_forward,n)
#   action_space((17,5),move_forward,n)
#   action_space((19,24),move_forward,n)
#   action_space((21,23),move_forward,n)
#   action_space((22,5),move_forward,n)
#   action_space((4,20),move_forward,w)
#   action_space((5,6),move_forward,w)
#   action_space((7,21),move_forward,w)
#   action_space((9,20),move_forward,w)
#   action_space((10,6),move_forward,w)
#   action_space((16,23),move_forward,w)
#   action_space((17,5),move_forward,w)
#   action_space((19,24),move_forward,w)
#   action_space((21,23),move_forward,w)
#   action_space((22,5),move_forward,w)
#   action_space((4,20),move_forward,s)
#   action_space((5,6),move_forward,s)
#   action_space((7,21),move_forward,s)
#   action_space((9,20),move_forward,s)
#   action_space((10,6),move_forward,s)
#   action_space((16,23),move_forward,s)
#   action_space((17,5),move_forward,s)
#   action_space((19,24),move_forward,s)
#   action_space((21,23),move_forward,s)
#   action_space((22,5),move_forward,s)
#   action_space((4,20),move_right,n)
#   action_space((5,6),move_right,n)
#   action_space((7,21),move_right,n)
#   action_space((9,20),move_right,n)
#   action_space((10,6),move_right,n)
#   action_space((16,23),move_right,n)
#   action_space((17,5),move_right,n)
#   action_space((19,24),move_right,n)
#   action_space((21,23),move_right,n)
#   action_space((22,5),move_right,n)
#   action_space((4,7),move_forward,e)
#   action_space((7,20),move_forward,e)
#   action_space((8,21),move_forward,e)
#   action_space((9,7),move_forward,e)
#   action_space((13,23),move_forward,e)
#   action_space((16,6),move_forward,e)
#   action_space((19,23),move_forward,e)
#   action_space((20,24),move_forward,e)
#   action_space((21,6),move_forward,e)
#   action_space((4,7),move_forward,n)
#   action_space((7,20),move_forward,n)
#   action_space((8,21),move_forward,n)
#   action_space((9,7),move_forward,n)
#   action_space((13,23),move_forward,n)
#   action_space((16,6),move_forward,n)
#   action_space((19,23),move_forward,n)
#   action_space((20,24),move_forward,n)
#   action_space((21,6),move_forward,n)
#   action_space((4,7),move_forward,s)
#   action_space((7,20),move_forward,s)
#   action_space((8,21),move_forward,s)
#   action_space((9,7),move_forward,s)
#   action_space((13,23),move_forward,s)
#   action_space((16,6),move_forward,s)
#   action_space((19,23),move_forward,s)
#   action_space((20,24),move_forward,s)
#   action_space((21,6),move_forward,s)
#   action_space((4,7),move_left,n)
#   action_space((7,20),move_left,n)
#   action_space((8,21),move_left,n)
#   action_space((9,7),move_left,n)
#   action_space((13,23),move_left,n)
#   action_space((16,6),move_left,n)
#   action_space((19,23),move_left,n)
#   action_space((20,24),move_left,n)
#   action_space((21,6),move_left,n)
#   action_space((1,20),move_forward,n)
#   action_space((3,21),move_forward,n)
#   action_space((5,22),move_forward,n)
#   action_space((11,23),move_forward,n)
#   action_space((12,21),move_forward,n)
#   action_space((15,24),move_forward,n)
#   action_space((17,25),move_forward,n)
#   action_space((1,20),move_forward,e)
#   action_space((3,21),move_forward,e)
#   action_space((5,22),move_forward,e)
#   action_space((11,23),move_forward,e)
#   action_space((12,21),move_forward,e)
#   action_space((15,24),move_forward,e)
#   action_space((17,25),move_forward,e)
#   action_space((2,20),move_forward,s)
#   action_space((3,6),move_forward,s)
#   action_space((3,7),move_forward,s)
#   action_space((6,6),move_forward,s)
#   action_space((6,7),move_forward,s)
#   action_space((6,19),move_forward,s)
#   action_space((6,20),move_forward,s)
#   action_space((6,21),move_forward,s)
#   action_space((6,22),move_forward,s)
#   action_space((7,6),move_forward,s)
#   action_space((7,7),move_forward,s)
#   action_space((8,6),move_forward,s)
#   action_space((8,7),move_forward,s)
#   action_space((10,20),move_forward,s)
#   action_space((11,6),move_forward,s)
#   action_space((11,7),move_forward,s)
#   action_space((12,6),move_forward,s)
#   action_space((12,7),move_forward,s)
#   action_space((12,23),move_forward,s)
#   action_space((13,6),move_forward,s)
#   action_space((13,7),move_forward,s)
#   action_space((14,23),move_forward,s)
#   action_space((15,5),move_forward,s)
#   action_space((15,6),move_forward,s)
#   action_space((18,5),move_forward,s)
#   action_space((18,6),move_forward,s)
#   action_space((18,22),move_forward,s)
#   action_space((18,23),move_forward,s)
#   action_space((18,24),move_forward,s)
#   action_space((18,25),move_forward,s)
#   action_space((19,5),move_forward,s)
#   action_space((19,6),move_forward,s)
#   action_space((20,5),move_forward,s)
#   action_space((20,6),move_forward,s)
#   action_space((22,23),move_forward,s)
#   action_space((23,5),move_forward,s)
#   action_space((23,6),move_forward,s)
#   action_space((2,20),move_forward,n)
#   action_space((3,6),move_forward,n)
#   action_space((3,7),move_forward,n)
#   action_space((6,6),move_forward,n)
#   action_space((6,7),move_forward,n)
#   action_space((6,19),move_forward,n)
#   action_space((6,20),move_forward,n)
#   action_space((6,21),move_forward,n)
#   action_space((6,22),move_forward,n)
#   action_space((7,6),move_forward,n)
#   action_space((7,7),move_forward,n)
#   action_space((8,6),move_forward,n)
#   action_space((8,7),move_forward,n)
#   action_space((10,20),move_forward,n)
#   action_space((11,6),move_forward,n)
#   action_space((11,7),move_forward,n)
#   action_space((12,6),move_forward,n)
#   action_space((12,7),move_forward,n)
#   action_space((12,23),move_forward,n)
#   action_space((13,6),move_forward,n)
#   action_space((13,7),move_forward,n)
#   action_space((14,23),move_forward,n)
#   action_space((15,5),move_forward,n)
#   action_space((15,6),move_forward,n)
#   action_space((18,5),move_forward,n)
#   action_space((18,6),move_forward,n)
#   action_space((18,22),move_forward,n)
#   action_space((18,23),move_forward,n)
#   action_space((18,24),move_forward,n)
#   action_space((18,25),move_forward,n)
#   action_space((19,5),move_forward,n)
#   action_space((19,6),move_forward,n)
#   action_space((20,5),move_forward,n)
#   action_space((20,6),move_forward,n)
#   action_space((22,23),move_forward,n)
#   action_space((23,5),move_forward,n)
#   action_space((23,6),move_forward,n)
#   action_space((14,6),wait,3)
#   action_space((14,6),wait,2)
#   action_space((14,6),wait,1)
#   action_space((14,6),wait,0)
#   action_space((4,20),wait,0)
#   action_space((5,6),wait,0)
#   action_space((7,21),wait,0)
#   action_space((9,20),wait,0)
#   action_space((10,6),wait,0)
#   action_space((16,23),wait,0)
#   action_space((17,5),wait,0)
#   action_space((19,24),wait,0)
#   action_space((21,23),wait,0)
#   action_space((22,5),wait,0)
#   action_space((4,20),wait,1)
#   action_space((5,6),wait,1)
#   action_space((7,21),wait,1)
#   action_space((9,20),wait,1)
#   action_space((10,6),wait,1)
#   action_space((16,23),wait,1)
#   action_space((17,5),wait,1)
#   action_space((19,24),wait,1)
#   action_space((21,23),wait,1)
#   action_space((22,5),wait,1)
#   action_space((4,20),wait,2)
#   action_space((5,6),wait,2)
#   action_space((7,21),wait,2)
#   action_space((9,20),wait,2)
#   action_space((10,6),wait,2)
#   action_space((16,23),wait,2)
#   action_space((17,5),wait,2)
#   action_space((19,24),wait,2)
#   action_space((21,23),wait,2)
#   action_space((22,5),wait,2)
#   action_space((4,7),wait,3)
#   action_space((7,20),wait,3)
#   action_space((8,21),wait,3)
#   action_space((9,7),wait,3)
#   action_space((13,23),wait,3)
#   action_space((16,6),wait,3)
#   action_space((19,23),wait,3)
#   action_space((20,24),wait,3)
#   action_space((21,6),wait,3)
#   action_space((4,7),wait,0)
#   action_space((7,20),wait,0)
#   action_space((8,21),wait,0)
#   action_space((9,7),wait,0)
#   action_space((13,23),wait,0)
#   action_space((16,6),wait,0)
#   action_space((19,23),wait,0)
#   action_space((20,24),wait,0)
#   action_space((21,6),wait,0)
#   action_space((4,7),wait,2)
#   action_space((7,20),wait,2)
#   action_space((8,21),wait,2)
#   action_space((9,7),wait,2)
#   action_space((13,23),wait,2)
#   action_space((16,6),wait,2)
#   action_space((19,23),wait,2)
#   action_space((20,24),wait,2)
#   action_space((21,6),wait,2)
#   action_space((1,20),wait,0)
#   action_space((3,21),wait,0)
#   action_space((5,22),wait,0)
#   action_space((11,23),wait,0)
#   action_space((12,21),wait,0)
#   action_space((15,24),wait,0)
#   action_space((17,25),wait,0)
#   action_space((1,20),wait,3)
#   action_space((3,21),wait,3)
#   action_space((5,22),wait,3)
#   action_space((11,23),wait,3)
#   action_space((12,21),wait,3)
#   action_space((15,24),wait,3)
#   action_space((17,25),wait,3)
#   action_space((2,20),wait,2)
#   action_space((3,6),wait,2)
#   action_space((3,7),wait,2)
#   action_space((6,6),wait,2)
#   action_space((6,7),wait,2)
#   action_space((6,19),wait,2)
#   action_space((6,20),wait,2)
#   action_space((6,21),wait,2)
#   action_space((6,22),wait,2)
#   action_space((7,6),wait,2)
#   action_space((7,7),wait,2)
#   action_space((8,6),wait,2)
#   action_space((8,7),wait,2)
#   action_space((10,20),wait,2)
#   action_space((11,6),wait,2)
#   action_space((11,7),wait,2)
#   action_space((12,6),wait,2)
#   action_space((12,7),wait,2)
#   action_space((12,23),wait,2)
#   action_space((13,6),wait,2)
#   action_space((13,7),wait,2)
#   action_space((14,23),wait,2)
#   action_space((15,5),wait,2)
#   action_space((15,6),wait,2)
#   action_space((18,5),wait,2)
#   action_space((18,6),wait,2)
#   action_space((18,22),wait,2)
#   action_space((18,23),wait,2)
#   action_space((18,24),wait,2)
#   action_space((18,25),wait,2)
#   action_space((19,5),wait,2)
#   action_space((19,6),wait,2)
#   action_space((20,5),wait,2)
#   action_space((20,6),wait,2)
#   action_space((22,23),wait,2)
#   action_space((23,5),wait,2)
#   action_space((23,6),wait,2)
#   action_space((2,20),wait,0)
#   action_space((3,6),wait,0)
#   action_space((3,7),wait,0)
#   action_space((6,6),wait,0)
#   action_space((6,7),wait,0)
#   action_space((6,19),wait,0)
#   action_space((6,20),wait,0)
#   action_space((6,21),wait,0)
#   action_space((6,22),wait,0)
#   action_space((7,6),wait,0)
#   action_space((7,7),wait,0)
#   action_space((8,6),wait,0)
#   action_space((8,7),wait,0)
#   action_space((10,20),wait,0)
#   action_space((11,6),wait,0)
#   action_space((11,7),wait,0)
#   action_space((12,6),wait,0)
#   action_space((12,7),wait,0)
#   action_space((12,23),wait,0)
#   action_space((13,6),wait,0)
#   action_space((13,7),wait,0)
#   action_space((14,23),wait,0)
#   action_space((15,5),wait,0)
#   action_space((15,6),wait,0)
#   action_space((18,5),wait,0)
#   action_space((18,6),wait,0)
#   action_space((18,22),wait,0)
#   action_space((18,23),wait,0)
#   action_space((18,24),wait,0)
#   action_space((18,25),wait,0)
#   action_space((19,5),wait,0)
#   action_space((19,6),wait,0)
#   action_space((20,5),wait,0)
#   action_space((20,6),wait,0)
#   action_space((22,23),wait,0)
#   action_space((23,5),wait,0)
#   action_space((23,6),wait,0)
#   action_space((24,6),move_forward,1)
#   action_space((4,21),move_forward,2)
#   action_space((5,7),move_forward,2)
#   action_space((5,20),move_forward,2)
#   action_space((10,7),move_forward,2)
#   action_space((16,24),move_forward,2)
#   action_space((17,6),move_forward,2)
#   action_space((17,23),move_forward,2)
#   action_space((22,6),move_forward,2)
#   action_space((23,23),move_forward,2)
#   action_space((24,6),move_forward,2)
#   action_space((4,21),move_forward,3)
#   action_space((5,7),move_forward,3)
#   action_space((5,20),move_forward,3)
#   action_space((10,7),move_forward,3)
#   action_space((16,24),move_forward,3)
#   action_space((17,6),move_forward,3)
#   action_space((17,23),move_forward,3)
#   action_space((22,6),move_forward,3)
#   action_space((23,23),move_forward,3)
#   action_space((24,6),move_forward,3)
#   action_space((4,21),move_forward,0)
#   action_space((5,7),move_forward,0)
#   action_space((5,20),move_forward,0)
#   action_space((10,7),move_forward,0)
#   action_space((16,24),move_forward,0)
#   action_space((17,6),move_forward,0)
#   action_space((17,23),move_forward,0)
#   action_space((22,6),move_forward,0)
#   action_space((23,23),move_forward,0)
#   action_space((24,6),move_right,1)
#   action_space((4,21),move_right,2)
#   action_space((5,7),move_right,2)
#   action_space((5,20),move_right,2)
#   action_space((10,7),move_right,2)
#   action_space((16,24),move_right,2)
#   action_space((17,6),move_right,2)
#   action_space((17,23),move_right,2)
#   action_space((22,6),move_right,2)
#   action_space((23,23),move_right,2)
#   action_space((1,15),move_forward,0)
#   action_space((2,7),move_forward,0)
#   action_space((23,12),move_forward,0)
#   action_space((3,20),move_forward,1)
#   action_space((4,6),move_forward,1)
#   action_space((5,21),move_forward,1)
#   action_space((8,20),move_forward,1)
#   action_space((9,6),move_forward,1)
#   action_space((11,20),move_forward,1)
#   action_space((15,23),move_forward,1)
#   action_space((16,5),move_forward,1)
#   action_space((17,24),move_forward,1)
#   action_space((20,23),move_forward,1)
#   action_space((21,5),move_forward,1)
#   action_space((2,13),move_forward,2)
#   action_space((24,10),move_forward,2)
#   action_space((24,12),move_forward,2)
#   action_space((1,15),move_forward,1)
#   action_space((2,7),move_forward,1)
#   action_space((23,12),move_forward,1)
#   action_space((3,20),move_forward,2)
#   action_space((4,6),move_forward,2)
#   action_space((5,21),move_forward,2)
#   action_space((8,20),move_forward,2)
#   action_space((9,6),move_forward,2)
#   action_space((11,20),move_forward,2)
#   action_space((15,23),move_forward,2)
#   action_space((16,5),move_forward,2)
#   action_space((17,24),move_forward,2)
#   action_space((20,23),move_forward,2)
#   action_space((21,5),move_forward,2)
#   action_space((2,13),move_forward,3)
#   action_space((24,10),move_forward,3)
#   action_space((24,12),move_forward,3)
#   action_space((1,15),move_forward,3)
#   action_space((2,7),move_forward,3)
#   action_space((23,12),move_forward,3)
#   action_space((3,20),move_forward,0)
#   action_space((4,6),move_forward,0)
#   action_space((5,21),move_forward,0)
#   action_space((8,20),move_forward,0)
#   action_space((9,6),move_forward,0)
#   action_space((11,20),move_forward,0)
#   action_space((15,23),move_forward,0)
#   action_space((16,5),move_forward,0)
#   action_space((17,24),move_forward,0)
#   action_space((20,23),move_forward,0)
#   action_space((21,5),move_forward,0)
#   action_space((2,13),move_forward,1)
#   action_space((24,10),move_forward,1)
#   action_space((24,12),move_forward,1)
#   action_space((1,15),move_left,1)
#   action_space((2,7),move_left,1)
#   action_space((23,12),move_left,1)
#   action_space((3,20),move_left,2)
#   action_space((4,6),move_left,2)
#   action_space((5,21),move_left,2)
#   action_space((8,20),move_left,2)
#   action_space((9,6),move_left,2)
#   action_space((11,20),move_left,2)
#   action_space((15,23),move_left,2)
#   action_space((16,5),move_left,2)
#   action_space((17,24),move_left,2)
#   action_space((20,23),move_left,2)
#   action_space((21,5),move_left,2)
#   action_space((2,13),move_left,3)
#   action_space((24,10),move_left,3)
#   action_space((24,12),move_left,3)
#   action_space((1,13),move_forward,1)
#   action_space((2,6),move_forward,1)
#   action_space((5,19),move_forward,1)
#   action_space((14,5),move_forward,1)
#   action_space((17,22),move_forward,1)
#   action_space((23,10),move_forward,1)
#   action_space((7,19),move_forward,2)
#   action_space((12,20),move_forward,2)
#   action_space((13,21),move_forward,2)
#   action_space((19,22),move_forward,2)
#   action_space((24,5),move_forward,2)
#   action_space((2,15),move_forward,3)
#   action_space((7,22),move_forward,3)
#   action_space((9,21),move_forward,3)
#   action_space((14,7),move_forward,3)
#   action_space((19,25),move_forward,3)
#   action_space((21,24),move_forward,3)
#   action_space((24,23),move_forward,3)
#   action_space((1,13),move_forward,0)
#   action_space((2,6),move_forward,0)
#   action_space((5,19),move_forward,0)
#   action_space((14,5),move_forward,0)
#   action_space((17,22),move_forward,0)
#   action_space((23,10),move_forward,0)
#   action_space((7,19),move_forward,1)
#   action_space((12,20),move_forward,1)
#   action_space((13,21),move_forward,1)
#   action_space((19,22),move_forward,1)
#   action_space((24,5),move_forward,1)
#   action_space((2,15),move_forward,2)
#   action_space((7,22),move_forward,2)
#   action_space((9,21),move_forward,2)
#   action_space((14,7),move_forward,2)
#   action_space((19,25),move_forward,2)
#   action_space((21,24),move_forward,2)
#   action_space((24,23),move_forward,2)
#   action_space((1,14),move_forward,3)
#   action_space((1,16),move_forward,3)
#   action_space((1,17),move_forward,3)
#   action_space((1,18),move_forward,3)
#   action_space((1,19),move_forward,3)
#   action_space((2,8),move_forward,3)
#   action_space((2,9),move_forward,3)
#   action_space((2,10),move_forward,3)
#   action_space((2,11),move_forward,3)
#   action_space((2,12),move_forward,3)
#   action_space((2,14),move_forward,3)
#   action_space((11,21),move_forward,3)
#   action_space((11,22),move_forward,3)
#   action_space((13,22),move_forward,3)
#   action_space((23,11),move_forward,3)
#   action_space((23,13),move_forward,3)
#   action_space((23,14),move_forward,3)
#   action_space((23,15),move_forward,3)
#   action_space((23,16),move_forward,3)
#   action_space((23,17),move_forward,3)
#   action_space((23,18),move_forward,3)
#   action_space((23,19),move_forward,3)
#   action_space((23,20),move_forward,3)
#   action_space((23,21),move_forward,3)
#   action_space((23,22),move_forward,3)
#   action_space((24,7),move_forward,3)
#   action_space((24,8),move_forward,3)
#   action_space((24,9),move_forward,3)
#   action_space((24,11),move_forward,3)
#   action_space((24,13),move_forward,3)
#   action_space((24,14),move_forward,3)
#   action_space((24,15),move_forward,3)
#   action_space((24,16),move_forward,3)
#   action_space((24,17),move_forward,3)
#   action_space((24,18),move_forward,3)
#   action_space((24,19),move_forward,3)
#   action_space((24,20),move_forward,3)
#   action_space((24,21),move_forward,3)
#   action_space((24,22),move_forward,3)
#   action_space((1,14),move_forward,1)
#   action_space((1,16),move_forward,1)
#   action_space((1,17),move_forward,1)
#   action_space((1,18),move_forward,1)
#   action_space((1,19),move_forward,1)
#   action_space((2,8),move_forward,1)
#   action_space((2,9),move_forward,1)
#   action_space((2,10),move_forward,1)
#   action_space((2,11),move_forward,1)
#   action_space((2,12),move_forward,1)
#   action_space((2,14),move_forward,1)
#   action_space((11,21),move_forward,1)
#   action_space((11,22),move_forward,1)
#   action_space((13,22),move_forward,1)
#   action_space((23,11),move_forward,1)
#   action_space((23,13),move_forward,1)
#   action_space((23,14),move_forward,1)
#   action_space((23,15),move_forward,1)
#   action_space((23,16),move_forward,1)
#   action_space((23,17),move_forward,1)
#   action_space((23,18),move_forward,1)
#   action_space((23,19),move_forward,1)
#   action_space((23,20),move_forward,1)
#   action_space((23,21),move_forward,1)
#   action_space((23,22),move_forward,1)
#   action_space((24,7),move_forward,1)
#   action_space((24,8),move_forward,1)
#   action_space((24,9),move_forward,1)
#   action_space((24,11),move_forward,1)
#   action_space((24,13),move_forward,1)
#   action_space((24,14),move_forward,1)
#   action_space((24,15),move_forward,1)
#   action_space((24,16),move_forward,1)
#   action_space((24,17),move_forward,1)
#   action_space((24,18),move_forward,1)
#   action_space((24,19),move_forward,1)
#   action_space((24,20),move_forward,1)
#   action_space((24,21),move_forward,1)
#   action_space((24,22),move_forward,1)
#   action_space((1,14),move_forward,w)
#   action_space((1,16),move_forward,w)
#   action_space((1,17),move_forward,w)
#   action_space((1,18),move_forward,w)
#   action_space((1,19),move_forward,w)
#   action_space((2,8),move_forward,w)
#   action_space((2,9),move_forward,w)
#   action_space((2,10),move_forward,w)
#   action_space((2,11),move_forward,w)
#   action_space((2,12),move_forward,w)
#   action_space((2,14),move_forward,w)
#   action_space((11,21),move_forward,w)
#   action_space((11,22),move_forward,w)
#   action_space((13,22),move_forward,w)
#   action_space((23,11),move_forward,w)
#   action_space((23,13),move_forward,w)
#   action_space((23,14),move_forward,w)
#   action_space((23,15),move_forward,w)
#   action_space((23,16),move_forward,w)
#   action_space((23,17),move_forward,w)
#   action_space((23,18),move_forward,w)
#   action_space((23,19),move_forward,w)
#   action_space((23,20),move_forward,w)
#   action_space((23,21),move_forward,w)
#   action_space((23,22),move_forward,w)
#   action_space((24,7),move_forward,w)
#   action_space((24,8),move_forward,w)
#   action_space((24,9),move_forward,w)
#   action_space((24,11),move_forward,w)
#   action_space((24,13),move_forward,w)
#   action_space((24,14),move_forward,w)
#   action_space((24,15),move_forward,w)
#   action_space((24,16),move_forward,w)
#   action_space((24,17),move_forward,w)
#   action_space((24,18),move_forward,w)
#   action_space((24,19),move_forward,w)
#   action_space((24,20),move_forward,w)
#   action_space((24,21),move_forward,w)
#   action_space((24,22),move_forward,w)
#   action_space((1,14),move_forward,e)
#   action_space((1,16),move_forward,e)
#   action_space((1,17),move_forward,e)
#   action_space((1,18),move_forward,e)
#   action_space((1,19),move_forward,e)
#   action_space((2,8),move_forward,e)
#   action_space((2,9),move_forward,e)
#   action_space((2,10),move_forward,e)
#   action_space((2,11),move_forward,e)
#   action_space((2,12),move_forward,e)
#   action_space((2,14),move_forward,e)
#   action_space((11,21),move_forward,e)
#   action_space((11,22),move_forward,e)
#   action_space((13,22),move_forward,e)
#   action_space((23,11),move_forward,e)
#   action_space((23,13),move_forward,e)
#   action_space((23,14),move_forward,e)
#   action_space((23,15),move_forward,e)
#   action_space((23,16),move_forward,e)
#   action_space((23,17),move_forward,e)
#   action_space((23,18),move_forward,e)
#   action_space((23,19),move_forward,e)
#   action_space((23,20),move_forward,e)
#   action_space((23,21),move_forward,e)
#   action_space((23,22),move_forward,e)
#   action_space((24,7),move_forward,e)
#   action_space((24,8),move_forward,e)
#   action_space((24,9),move_forward,e)
#   action_space((24,11),move_forward,e)
#   action_space((24,13),move_forward,e)
#   action_space((24,14),move_forward,e)
#   action_space((24,15),move_forward,e)
#   action_space((24,16),move_forward,e)
#   action_space((24,17),move_forward,e)
#   action_space((24,18),move_forward,e)
#   action_space((24,19),move_forward,e)
#   action_space((24,20),move_forward,e)
#   action_space((24,21),move_forward,e)
#   action_space((24,22),move_forward,e)
#   action_space((2,15),move_forward,s)
#   action_space((7,22),move_forward,s)
#   action_space((9,21),move_forward,s)
#   action_space((14,7),move_forward,s)
#   action_space((19,25),move_forward,s)
#   action_space((21,24),move_forward,s)
#   action_space((24,23),move_forward,s)
#   action_space((7,19),move_forward,w)
#   action_space((12,20),move_forward,w)
#   action_space((13,21),move_forward,w)
#   action_space((19,22),move_forward,w)
#   action_space((24,5),move_forward,w)
#   action_space((1,13),move_forward,n)
#   action_space((2,6),move_forward,n)
#   action_space((5,19),move_forward,n)
#   action_space((14,5),move_forward,n)
#   action_space((17,22),move_forward,n)
#   action_space((23,10),move_forward,n)
#   action_space((2,15),move_forward,e)
#   action_space((7,22),move_forward,e)
#   action_space((9,21),move_forward,e)
#   action_space((14,7),move_forward,e)
#   action_space((19,25),move_forward,e)
#   action_space((21,24),move_forward,e)
#   action_space((24,23),move_forward,e)
#   action_space((7,19),move_forward,s)
#   action_space((12,20),move_forward,s)
#   action_space((13,21),move_forward,s)
#   action_space((19,22),move_forward,s)
#   action_space((24,5),move_forward,s)
#   action_space((1,13),move_forward,w)
#   action_space((2,6),move_forward,w)
#   action_space((5,19),move_forward,w)
#   action_space((14,5),move_forward,w)
#   action_space((17,22),move_forward,w)
#   action_space((23,10),move_forward,w)
#   action_space((2,13),move_left,e)
#   action_space((24,10),move_left,e)
#   action_space((24,12),move_left,e)
#   action_space((3,20),move_left,s)
#   action_space((4,6),move_left,s)
#   action_space((5,21),move_left,s)
#   action_space((8,20),move_left,s)
#   action_space((9,6),move_left,s)
#   action_space((11,20),move_left,s)
#   action_space((15,23),move_left,s)
#   action_space((16,5),move_left,s)
#   action_space((17,24),move_left,s)
#   action_space((20,23),move_left,s)
#   action_space((21,5),move_left,s)
#   action_space((1,15),move_left,w)
#   action_space((2,7),move_left,w)
#   action_space((23,12),move_left,w)
#   action_space((2,13),move_forward,w)
#   action_space((24,10),move_forward,w)
#   action_space((24,12),move_forward,w)
#   action_space((3,20),move_forward,n)
#   action_space((4,6),move_forward,n)
#   action_space((5,21),move_forward,n)
#   action_space((8,20),move_forward,n)
#   action_space((9,6),move_forward,n)
#   action_space((11,20),move_forward,n)
#   action_space((15,23),move_forward,n)
#   action_space((16,5),move_forward,n)
#   action_space((17,24),move_forward,n)
#   action_space((20,23),move_forward,n)
#   action_space((21,5),move_forward,n)
#   action_space((1,15),move_forward,e)
#   action_space((2,7),move_forward,e)
#   action_space((23,12),move_forward,e)
#   action_space((2,13),move_forward,e)
#   action_space((24,10),move_forward,e)
#   action_space((24,12),move_forward,e)
#   action_space((3,20),move_forward,s)
#   action_space((4,6),move_forward,s)
#   action_space((5,21),move_forward,s)
#   action_space((8,20),move_forward,s)
#   action_space((9,6),move_forward,s)
#   action_space((11,20),move_forward,s)
#   action_space((15,23),move_forward,s)
#   action_space((16,5),move_forward,s)
#   action_space((17,24),move_forward,s)
#   action_space((20,23),move_forward,s)
#   action_space((21,5),move_forward,s)
#   action_space((1,15),move_forward,w)
#   action_space((2,7),move_forward,w)
#   action_space((23,12),move_forward,w)
#   action_space((2,13),move_forward,s)
#   action_space((24,10),move_forward,s)
#   action_space((24,12),move_forward,s)
#   action_space((3,20),move_forward,w)
#   action_space((4,6),move_forward,w)
#   action_space((5,21),move_forward,w)
#   action_space((8,20),move_forward,w)
#   action_space((9,6),move_forward,w)
#   action_space((11,20),move_forward,w)
#   action_space((15,23),move_forward,w)
#   action_space((16,5),move_forward,w)
#   action_space((17,24),move_forward,w)
#   action_space((20,23),move_forward,w)
#   action_space((21,5),move_forward,w)
#   action_space((1,15),move_forward,n)
#   action_space((2,7),move_forward,n)
#   action_space((23,12),move_forward,n)
#   action_space((4,21),move_right,s)
#   action_space((5,7),move_right,s)
#   action_space((5,20),move_right,s)
#   action_space((10,7),move_right,s)
#   action_space((16,24),move_right,s)
#   action_space((17,6),move_right,s)
#   action_space((17,23),move_right,s)
#   action_space((22,6),move_right,s)
#   action_space((23,23),move_right,s)
#   action_space((24,6),move_right,w)
#   action_space((4,21),move_forward,n)
#   action_space((5,7),move_forward,n)
#   action_space((5,20),move_forward,n)
#   action_space((10,7),move_forward,n)
#   action_space((16,24),move_forward,n)
#   action_space((17,6),move_forward,n)
#   action_space((17,23),move_forward,n)
#   action_space((22,6),move_forward,n)
#   action_space((23,23),move_forward,n)
#   action_space((24,6),move_forward,e)
#   action_space((4,21),move_forward,e)
#   action_space((5,7),move_forward,e)
#   action_space((5,20),move_forward,e)
#   action_space((10,7),move_forward,e)
#   action_space((16,24),move_forward,e)
#   action_space((17,6),move_forward,e)
#   action_space((17,23),move_forward,e)
#   action_space((22,6),move_forward,e)
#   action_space((23,23),move_forward,e)
#   action_space((24,6),move_forward,s)
#   action_space((4,21),move_forward,s)
#   action_space((5,7),move_forward,s)
#   action_space((5,20),move_forward,s)
#   action_space((10,7),move_forward,s)
#   action_space((16,24),move_forward,s)
#   action_space((17,6),move_forward,s)
#   action_space((17,23),move_forward,s)
#   action_space((22,6),move_forward,s)
#   action_space((23,23),move_forward,s)
#   action_space((24,6),move_forward,w)
#   action_space((2,20),wait,n)
#   action_space((3,6),wait,n)
#   action_space((3,7),wait,n)
#   action_space((6,6),wait,n)
#   action_space((6,7),wait,n)
#   action_space((6,19),wait,n)
#   action_space((6,20),wait,n)
#   action_space((6,21),wait,n)
#   action_space((6,22),wait,n)
#   action_space((7,6),wait,n)
#   action_space((7,7),wait,n)
#   action_space((8,6),wait,n)
#   action_space((8,7),wait,n)
#   action_space((10,20),wait,n)
#   action_space((11,6),wait,n)
#   action_space((11,7),wait,n)
#   action_space((12,6),wait,n)
#   action_space((12,7),wait,n)
#   action_space((12,23),wait,n)
#   action_space((13,6),wait,n)
#   action_space((13,7),wait,n)
#   action_space((14,23),wait,n)
#   action_space((15,5),wait,n)
#   action_space((15,6),wait,n)
#   action_space((18,5),wait,n)
#   action_space((18,6),wait,n)
#   action_space((18,22),wait,n)
#   action_space((18,23),wait,n)
#   action_space((18,24),wait,n)
#   action_space((18,25),wait,n)
#   action_space((19,5),wait,n)
#   action_space((19,6),wait,n)
#   action_space((20,5),wait,n)
#   action_space((20,6),wait,n)
#   action_space((22,23),wait,n)
#   action_space((23,5),wait,n)
#   action_space((23,6),wait,n)
#   action_space((2,20),wait,s)
#   action_space((3,6),wait,s)
#   action_space((3,7),wait,s)
#   action_space((6,6),wait,s)
#   action_space((6,7),wait,s)
#   action_space((6,19),wait,s)
#   action_space((6,20),wait,s)
#   action_space((6,21),wait,s)
#   action_space((6,22),wait,s)
#   action_space((7,6),wait,s)
#   action_space((7,7),wait,s)
#   action_space((8,6),wait,s)
#   action_space((8,7),wait,s)
#   action_space((10,20),wait,s)
#   action_space((11,6),wait,s)
#   action_space((11,7),wait,s)
#   action_space((12,6),wait,s)
#   action_space((12,7),wait,s)
#   action_space((12,23),wait,s)
#   action_space((13,6),wait,s)
#   action_space((13,7),wait,s)
#   action_space((14,23),wait,s)
#   action_space((15,5),wait,s)
#   action_space((15,6),wait,s)
#   action_space((18,5),wait,s)
#   action_space((18,6),wait,s)
#   action_space((18,22),wait,s)
#   action_space((18,23),wait,s)
#   action_space((18,24),wait,s)
#   action_space((18,25),wait,s)
#   action_space((19,5),wait,s)
#   action_space((19,6),wait,s)
#   action_space((20,5),wait,s)
#   action_space((20,6),wait,s)
#   action_space((22,23),wait,s)
#   action_space((23,5),wait,s)
#   action_space((23,6),wait,s)
#   action_space((1,20),wait,e)
#   action_space((3,21),wait,e)
#   action_space((5,22),wait,e)
#   action_space((11,23),wait,e)
#   action_space((12,21),wait,e)
#   action_space((15,24),wait,e)
#   action_space((17,25),wait,e)
#   action_space((1,20),wait,n)
#   action_space((3,21),wait,n)
#   action_space((5,22),wait,n)
#   action_space((11,23),wait,n)
#   action_space((12,21),wait,n)
#   action_space((15,24),wait,n)
#   action_space((17,25),wait,n)
#   action_space((4,7),wait,n)
#   action_space((7,20),wait,n)
#   action_space((8,21),wait,n)
#   action_space((9,7),wait,n)
#   action_space((13,23),wait,n)
#   action_space((16,6),wait,n)
#   action_space((19,23),wait,n)
#   action_space((20,24),wait,n)
#   action_space((21,6),wait,n)
#   action_space((4,7),wait,s)
#   action_space((7,20),wait,s)
#   action_space((8,21),wait,s)
#   action_space((9,7),wait,s)
#   action_space((13,23),wait,s)
#   action_space((16,6),wait,s)
#   action_space((19,23),wait,s)
#   action_space((20,24),wait,s)
#   action_space((21,6),wait,s)
#   action_space((4,7),wait,e)
#   action_space((7,20),wait,e)
#   action_space((8,21),wait,e)
#   action_space((9,7),wait,e)
#   action_space((13,23),wait,e)
#   action_space((16,6),wait,e)
#   action_space((19,23),wait,e)
#   action_space((20,24),wait,e)
#   action_space((21,6),wait,e)
#   action_space((4,20),wait,n)
#   action_space((5,6),wait,n)
#   action_space((7,21),wait,n)
#   action_space((9,20),wait,n)
#   action_space((10,6),wait,n)
#   action_space((16,23),wait,n)
#   action_space((17,5),wait,n)
#   action_space((19,24),wait,n)
#   action_space((21,23),wait,n)
#   action_space((22,5),wait,n)
#   action_space((4,20),wait,s)
#   action_space((5,6),wait,s)
#   action_space((7,21),wait,s)
#   action_space((9,20),wait,s)
#   action_space((10,6),wait,s)
#   action_space((16,23),wait,s)
#   action_space((17,5),wait,s)
#   action_space((19,24),wait,s)
#   action_space((21,23),wait,s)
#   action_space((22,5),wait,s)
#   action_space((4,20),wait,w)
#   action_space((5,6),wait,w)
#   action_space((7,21),wait,w)
#   action_space((9,20),wait,w)
#   action_space((10,6),wait,w)
#   action_space((16,23),wait,w)
#   action_space((17,5),wait,w)
#   action_space((19,24),wait,w)
#   action_space((21,23),wait,w)
#   action_space((22,5),wait,w)
#   action_space((14,6),wait,n)
#   action_space((14,6),wait,e)
#   action_space((14,6),wait,w)
#   action_space((14,6),wait,s)
#   action_space((1,14),wait,1)
#   action_space((1,16),wait,1)
#   action_space((1,17),wait,1)
#   action_space((1,18),wait,1)
#   action_space((1,19),wait,1)
#   action_space((2,8),wait,1)
#   action_space((2,9),wait,1)
#   action_space((2,10),wait,1)
#   action_space((2,11),wait,1)
#   action_space((2,12),wait,1)
#   action_space((2,14),wait,1)
#   action_space((11,21),wait,1)
#   action_space((11,22),wait,1)
#   action_space((13,22),wait,1)
#   action_space((23,11),wait,1)
#   action_space((23,13),wait,1)
#   action_space((23,14),wait,1)
#   action_space((23,15),wait,1)
#   action_space((23,16),wait,1)
#   action_space((23,17),wait,1)
#   action_space((23,18),wait,1)
#   action_space((23,19),wait,1)
#   action_space((23,20),wait,1)
#   action_space((23,21),wait,1)
#   action_space((23,22),wait,1)
#   action_space((24,7),wait,1)
#   action_space((24,8),wait,1)
#   action_space((24,9),wait,1)
#   action_space((24,11),wait,1)
#   action_space((24,13),wait,1)
#   action_space((24,14),wait,1)
#   action_space((24,15),wait,1)
#   action_space((24,16),wait,1)
#   action_space((24,17),wait,1)
#   action_space((24,18),wait,1)
#   action_space((24,19),wait,1)
#   action_space((24,20),wait,1)
#   action_space((24,21),wait,1)
#   action_space((24,22),wait,1)
#   action_space((1,14),wait,3)
#   action_space((1,16),wait,3)
#   action_space((1,17),wait,3)
#   action_space((1,18),wait,3)
#   action_space((1,19),wait,3)
#   action_space((2,8),wait,3)
#   action_space((2,9),wait,3)
#   action_space((2,10),wait,3)
#   action_space((2,11),wait,3)
#   action_space((2,12),wait,3)
#   action_space((2,14),wait,3)
#   action_space((11,21),wait,3)
#   action_space((11,22),wait,3)
#   action_space((13,22),wait,3)
#   action_space((23,11),wait,3)
#   action_space((23,13),wait,3)
#   action_space((23,14),wait,3)
#   action_space((23,15),wait,3)
#   action_space((23,16),wait,3)
#   action_space((23,17),wait,3)
#   action_space((23,18),wait,3)
#   action_space((23,19),wait,3)
#   action_space((23,20),wait,3)
#   action_space((23,21),wait,3)
#   action_space((23,22),wait,3)
#   action_space((24,7),wait,3)
#   action_space((24,8),wait,3)
#   action_space((24,9),wait,3)
#   action_space((24,11),wait,3)
#   action_space((24,13),wait,3)
#   action_space((24,14),wait,3)
#   action_space((24,15),wait,3)
#   action_space((24,16),wait,3)
#   action_space((24,17),wait,3)
#   action_space((24,18),wait,3)
#   action_space((24,19),wait,3)
#   action_space((24,20),wait,3)
#   action_space((24,21),wait,3)
#   action_space((24,22),wait,3)
#   action_space((2,15),wait,2)
#   action_space((7,22),wait,2)
#   action_space((9,21),wait,2)
#   action_space((14,7),wait,2)
#   action_space((19,25),wait,2)
#   action_space((21,24),wait,2)
#   action_space((24,23),wait,2)
#   action_space((7,19),wait,1)
#   action_space((12,20),wait,1)
#   action_space((13,21),wait,1)
#   action_space((19,22),wait,1)
#   action_space((24,5),wait,1)
#   action_space((1,13),wait,0)
#   action_space((2,6),wait,0)
#   action_space((5,19),wait,0)
#   action_space((14,5),wait,0)
#   action_space((17,22),wait,0)
#   action_space((23,10),wait,0)
#   action_space((2,15),wait,3)
#   action_space((7,22),wait,3)
#   action_space((9,21),wait,3)
#   action_space((14,7),wait,3)
#   action_space((19,25),wait,3)
#   action_space((21,24),wait,3)
#   action_space((24,23),wait,3)
#   action_space((7,19),wait,2)
#   action_space((12,20),wait,2)
#   action_space((13,21),wait,2)
#   action_space((19,22),wait,2)
#   action_space((24,5),wait,2)
#   action_space((1,13),wait,1)
#   action_space((2,6),wait,1)
#   action_space((5,19),wait,1)
#   action_space((14,5),wait,1)
#   action_space((17,22),wait,1)
#   action_space((23,10),wait,1)
#   action_space((2,13),wait,3)
#   action_space((24,10),wait,3)
#   action_space((24,12),wait,3)
#   action_space((3,20),wait,2)
#   action_space((4,6),wait,2)
#   action_space((5,21),wait,2)
#   action_space((8,20),wait,2)
#   action_space((9,6),wait,2)
#   action_space((11,20),wait,2)
#   action_space((15,23),wait,2)
#   action_space((16,5),wait,2)
#   action_space((17,24),wait,2)
#   action_space((20,23),wait,2)
#   action_space((21,5),wait,2)
#   action_space((1,15),wait,1)
#   action_space((2,7),wait,1)
#   action_space((23,12),wait,1)
#   action_space((2,13),wait,1)
#   action_space((24,10),wait,1)
#   action_space((24,12),wait,1)
#   action_space((3,20),wait,0)
#   action_space((4,6),wait,0)
#   action_space((5,21),wait,0)
#   action_space((8,20),wait,0)
#   action_space((9,6),wait,0)
#   action_space((11,20),wait,0)
#   action_space((15,23),wait,0)
#   action_space((16,5),wait,0)
#   action_space((17,24),wait,0)
#   action_space((20,23),wait,0)
#   action_space((21,5),wait,0)
#   action_space((1,15),wait,3)
#   action_space((2,7),wait,3)
#   action_space((23,12),wait,3)
#   action_space((2,13),wait,2)
#   action_space((24,10),wait,2)
#   action_space((24,12),wait,2)
#   action_space((3,20),wait,1)
#   action_space((4,6),wait,1)
#   action_space((5,21),wait,1)
#   action_space((8,20),wait,1)
#   action_space((9,6),wait,1)
#   action_space((11,20),wait,1)
#   action_space((15,23),wait,1)
#   action_space((16,5),wait,1)
#   action_space((17,24),wait,1)
#   action_space((20,23),wait,1)
#   action_space((21,5),wait,1)
#   action_space((1,15),wait,0)
#   action_space((2,7),wait,0)
#   action_space((23,12),wait,0)
#   action_space((4,21),wait,2)
#   action_space((5,7),wait,2)
#   action_space((5,20),wait,2)
#   action_space((10,7),wait,2)
#   action_space((16,24),wait,2)
#   action_space((17,6),wait,2)
#   action_space((17,23),wait,2)
#   action_space((22,6),wait,2)
#   action_space((23,23),wait,2)
#   action_space((24,6),wait,1)
#   action_space((4,21),wait,0)
#   action_space((5,7),wait,0)
#   action_space((5,20),wait,0)
#   action_space((10,7),wait,0)
#   action_space((16,24),wait,0)
#   action_space((17,6),wait,0)
#   action_space((17,23),wait,0)
#   action_space((22,6),wait,0)
#   action_space((23,23),wait,0)
#   action_space((24,6),wait,3)
#   action_space((4,21),wait,3)
#   action_space((5,7),wait,3)
#   action_space((5,20),wait,3)
#   action_space((10,7),wait,3)
#   action_space((16,24),wait,3)
#   action_space((17,6),wait,3)
#   action_space((17,23),wait,3)
#   action_space((22,6),wait,3)
#   action_space((23,23),wait,3)
#   action_space((24,6),wait,2)
#   action_space((24,6),wait,w)
#   action_space((4,21),wait,s)
#   action_space((5,7),wait,s)
#   action_space((5,20),wait,s)
#   action_space((10,7),wait,s)
#   action_space((16,24),wait,s)
#   action_space((17,6),wait,s)
#   action_space((17,23),wait,s)
#   action_space((22,6),wait,s)
#   action_space((23,23),wait,s)
#   action_space((24,6),wait,s)
#   action_space((4,21),wait,e)
#   action_space((5,7),wait,e)
#   action_space((5,20),wait,e)
#   action_space((10,7),wait,e)
#   action_space((16,24),wait,e)
#   action_space((17,6),wait,e)
#   action_space((17,23),wait,e)
#   action_space((22,6),wait,e)
#   action_space((23,23),wait,e)
#   action_space((24,6),wait,e)
#   action_space((4,21),wait,n)
#   action_space((5,7),wait,n)
#   action_space((5,20),wait,n)
#   action_space((10,7),wait,n)
#   action_space((16,24),wait,n)
#   action_space((17,6),wait,n)
#   action_space((17,23),wait,n)
#   action_space((22,6),wait,n)
#   action_space((23,23),wait,n)
#   action_space((1,15),wait,n)
#   action_space((2,7),wait,n)
#   action_space((23,12),wait,n)
#   action_space((3,20),wait,w)
#   action_space((4,6),wait,w)
#   action_space((5,21),wait,w)
#   action_space((8,20),wait,w)
#   action_space((9,6),wait,w)
#   action_space((11,20),wait,w)
#   action_space((15,23),wait,w)
#   action_space((16,5),wait,w)
#   action_space((17,24),wait,w)
#   action_space((20,23),wait,w)
#   action_space((21,5),wait,w)
#   action_space((2,13),wait,s)
#   action_space((24,10),wait,s)
#   action_space((24,12),wait,s)
#   action_space((1,15),wait,w)
#   action_space((2,7),wait,w)
#   action_space((23,12),wait,w)
#   action_space((3,20),wait,s)
#   action_space((4,6),wait,s)
#   action_space((5,21),wait,s)
#   action_space((8,20),wait,s)
#   action_space((9,6),wait,s)
#   action_space((11,20),wait,s)
#   action_space((15,23),wait,s)
#   action_space((16,5),wait,s)
#   action_space((17,24),wait,s)
#   action_space((20,23),wait,s)
#   action_space((21,5),wait,s)
#   action_space((2,13),wait,e)
#   action_space((24,10),wait,e)
#   action_space((24,12),wait,e)
#   action_space((1,15),wait,e)
#   action_space((2,7),wait,e)
#   action_space((23,12),wait,e)
#   action_space((3,20),wait,n)
#   action_space((4,6),wait,n)
#   action_space((5,21),wait,n)
#   action_space((8,20),wait,n)
#   action_space((9,6),wait,n)
#   action_space((11,20),wait,n)
#   action_space((15,23),wait,n)
#   action_space((16,5),wait,n)
#   action_space((17,24),wait,n)
#   action_space((20,23),wait,n)
#   action_space((21,5),wait,n)
#   action_space((2,13),wait,w)
#   action_space((24,10),wait,w)
#   action_space((24,12),wait,w)
#   action_space((1,13),wait,w)
#   action_space((2,6),wait,w)
#   action_space((5,19),wait,w)
#   action_space((14,5),wait,w)
#   action_space((17,22),wait,w)
#   action_space((23,10),wait,w)
#   action_space((7,19),wait,s)
#   action_space((12,20),wait,s)
#   action_space((13,21),wait,s)
#   action_space((19,22),wait,s)
#   action_space((24,5),wait,s)
#   action_space((2,15),wait,e)
#   action_space((7,22),wait,e)
#   action_space((9,21),wait,e)
#   action_space((14,7),wait,e)
#   action_space((19,25),wait,e)
#   action_space((21,24),wait,e)
#   action_space((24,23),wait,e)
#   action_space((1,13),wait,n)
#   action_space((2,6),wait,n)
#   action_space((5,19),wait,n)
#   action_space((14,5),wait,n)
#   action_space((17,22),wait,n)
#   action_space((23,10),wait,n)
#   action_space((7,19),wait,w)
#   action_space((12,20),wait,w)
#   action_space((13,21),wait,w)
#   action_space((19,22),wait,w)
#   action_space((24,5),wait,w)
#   action_space((2,15),wait,s)
#   action_space((7,22),wait,s)
#   action_space((9,21),wait,s)
#   action_space((14,7),wait,s)
#   action_space((19,25),wait,s)
#   action_space((21,24),wait,s)
#   action_space((24,23),wait,s)
#   action_space((1,14),wait,e)
#   action_space((1,16),wait,e)
#   action_space((1,17),wait,e)
#   action_space((1,18),wait,e)
#   action_space((1,19),wait,e)
#   action_space((2,8),wait,e)
#   action_space((2,9),wait,e)
#   action_space((2,10),wait,e)
#   action_space((2,11),wait,e)
#   action_space((2,12),wait,e)
#   action_space((2,14),wait,e)
#   action_space((11,21),wait,e)
#   action_space((11,22),wait,e)
#   action_space((13,22),wait,e)
#   action_space((23,11),wait,e)
#   action_space((23,13),wait,e)
#   action_space((23,14),wait,e)
#   action_space((23,15),wait,e)
#   action_space((23,16),wait,e)
#   action_space((23,17),wait,e)
#   action_space((23,18),wait,e)
#   action_space((23,19),wait,e)
#   action_space((23,20),wait,e)
#   action_space((23,21),wait,e)
#   action_space((23,22),wait,e)
#   action_space((24,7),wait,e)
#   action_space((24,8),wait,e)
#   action_space((24,9),wait,e)
#   action_space((24,11),wait,e)
#   action_space((24,13),wait,e)
#   action_space((24,14),wait,e)
#   action_space((24,15),wait,e)
#   action_space((24,16),wait,e)
#   action_space((24,17),wait,e)
#   action_space((24,18),wait,e)
#   action_space((24,19),wait,e)
#   action_space((24,20),wait,e)
#   action_space((24,21),wait,e)
#   action_space((24,22),wait,e)
#   action_space((1,14),wait,w)
#   action_space((1,16),wait,w)
#   action_space((1,17),wait,w)
#   action_space((1,18),wait,w)
#   action_space((1,19),wait,w)
#   action_space((2,8),wait,w)
#   action_space((2,9),wait,w)
#   action_space((2,10),wait,w)
#   action_space((2,11),wait,w)
#   action_space((2,12),wait,w)
#   action_space((2,14),wait,w)
#   action_space((11,21),wait,w)
#   action_space((11,22),wait,w)
#   action_space((13,22),wait,w)
#   action_space((23,11),wait,w)
#   action_space((23,13),wait,w)
#   action_space((23,14),wait,w)
#   action_space((23,15),wait,w)
#   action_space((23,16),wait,w)
#   action_space((23,17),wait,w)
#   action_space((23,18),wait,w)
#   action_space((23,19),wait,w)
#   action_space((23,20),wait,w)
#   action_space((23,21),wait,w)
#   action_space((23,22),wait,w)
#   action_space((24,7),wait,w)
#   action_space((24,8),wait,w)
#   action_space((24,9),wait,w)
#   action_space((24,11),wait,w)
#   action_space((24,13),wait,w)
#   action_space((24,14),wait,w)
#   action_space((24,15),wait,w)
#   action_space((24,16),wait,w)
#   action_space((24,17),wait,w)
#   action_space((24,18),wait,w)
#   action_space((24,19),wait,w)
#   action_space((24,20),wait,w)
#   action_space((24,21),wait,w)
#   action_space((24,22),wait,w)
#   action(train(0),wait,0)
#   action(train(0),wait,1)
#   action(train(0),wait,2)
#   action(train(0),wait,3)
#   action(train(0),wait,4)
#   action(train(0),move_forward,5)
#   action(train(0),wait,6)
#   action(train(0),wait,7)
#   action(train(0),wait,8)
#   action(train(0),wait,9)
#   action(train(0),wait,10)
#   action(train(0),wait,11)
#   action(train(0),wait,12)
#   action(train(0),wait,13)
#   action(train(0),wait,14)
#   action(train(0),wait,15)
#   action(train(0),wait,16)
#   action(train(0),wait,17)
#   action(train(0),wait,18)
#   action(train(0),wait,19)
#   action(train(0),wait,20)
#   action(train(0),wait,21)
#   action(train(0),wait,22)
#   action(train(0),move_forward,23)
#   action(train(0),move_forward,24)
#   action(train(0),move_right,25)
#   action(train(0),move_forward,26)
#   action(train(0),move_forward,27)
#   action(train(0),move_forward,28)
#   action(train(0),move_forward,29)
#   action(train(0),move_forward,30)
#   action(train(0),move_forward,31)
#   action(train(0),move_forward,32)
#   action(train(0),move_forward,33)
#   action(train(0),move_forward,34)
#   action(train(0),move_forward,35)
#   action(train(0),move_forward,36)
#   action(train(0),move_forward,37)
#   action(train(0),move_forward,38)
#   action(train(0),move_forward,39)
#   action(train(0),move_forward,40)
#   action(train(0),move_forward,41)
#   action(train(0),move_forward,42)
#   action(train(0),move_forward,43)
#   action(train(0),move_forward,44)
#   action(train(0),move_forward,45)
#   action(train(0),move_forward,46)
#   action(train(0),move_forward,47)
#   action(train(0),move_forward,48)
#   action(train(0),move_forward,49)
#   action(train(0),move_forward,50)
#   action(train(0),move_forward,51)
#   action(train(0),move_forward,52)
#   action(train(0),move_left,53)
#   action(train(0),move_forward,54)
#   action(train(0),move_forward,55)
#   action(train(0),move_forward,56)
#   action(train(0),move_forward,57)
#   action(train(0),move_forward,58)
#   action(train(0),move_forward,59)
#   action(train(0),move_forward,60)
#   action(train(0),move_forward,61)
#   action(train(0),move_forward,62)
#   action(train(0),wait,63)
# SAT
