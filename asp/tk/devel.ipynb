# %%
# %%clingo --time-limit=10 --opt-mode=optN tracks.lp encoding.lp env_001--2_6.lp -
#
# %# show action/3.
# %#show arrived/2.
# %#show state/4.
# Out:
# clingo version 5.8.0
# Reading from tracks.lp ...
# Solving...
# Answer: 1 (Time: 0.555s)
# arrived(0,33) arrived(1,37) action_count(0,22) action_count(1,34)
# Optimization: 56
# Answer: 1 (Time: 0.586s)
# arrived(0,33) arrived(1,37) action_count(0,22) action_count(1,34)
# Optimization: 56
# Answer: 2 (Time: 0.586s)
# arrived(0,33) arrived(1,37) action_count(0,22) action_count(1,34)
# Optimization: 56
# OPTIMUM FOUND
#
# Models       : 3
#   Optimum    : yes
#   Optimal    : 2
# Optimization : 56
# Calls        : 1
# Time         : 0.589s (Solving: 0.04s 1st Model: 0.00s Unsat: 0.00s)
# CPU Time     : 0.564s

# %%
from clingo import Control

env_encoding_file = "env_001--2_6.lp"
tracks_file = "tracks.lp"
encoding_file = "encoding.lp"
# ctl = Control(["0"])
ctl = Control()
ctl.load(env_encoding_file)
ctl.load(tracks_file)
ctl.load(encoding_file)
ctl.ground()
grid = {}
with ctl.solve(yield_ = True) as handle:
    for i, model in enumerate(handle):
        print(f"Model #{i}:")
        for symbol in model.symbols(shown = True):
            if symbol.name in ["action", "state", "arrived"]:
                print(f"  {symbol}")
            # if symbol.name == "action_space":
            #     print(f"  {symbol}")
            #     # if symbol.arguments[0].arguments:
            #         x = symbol.arguments[0].arguments[0].number
            #         y = symbol.arguments[0].arguments[1].number
            #         if x == 7 and y == 6:
            #             print(f"  action_space at ({x},{y}): {symbol}")
    print(handle.get())
# Out:
# Model #0:
#   action(train(0),move_forward,11)
#   action(train(1),move_forward,3)
#   action(train(0),move_forward,12)
#   action(train(1),move_forward,4)
#   action(train(1),move_forward,5)
#   action(train(0),move_forward,13)
#   action(train(0),move_forward,14)
#   action(train(1),move_forward,6)
#   action(train(1),move_forward,7)
#   action(train(0),move_forward,15)
#   action(train(0),move_forward,16)
#   action(train(1),move_forward,8)
#   action(train(1),move_forward,9)
#   action(train(0),move_forward,17)
#   action(train(0),move_forward,18)
#   action(train(1),move_forward,10)
#   action(train(1),move_forward,11)
#   action(train(0),move_forward,19)
#   action(train(0),move_forward,20)
#   action(train(1),move_forward,12)
#   action(train(1),move_forward,13)
#   action(train(0),move_forward,21)
#   action(train(0),move_forward,22)
#   action(train(1),move_forward,14)
#   action(train(1),move_forward,15)
#   action(train(0),move_forward,23)
#   action(train(0),move_forward,24)
#   action(train(1),move_forward,16)
#   action(train(1),move_forward,17)
#   action(train(0),move_forward,25)
#   action(train(0),move_forward,26)
#   action(train(1),move_forward,18)
#   action(train(1),move_forward,19)
#   action(train(0),move_forward,27)
#   action(train(0),move_forward,28)
#   action(train(1),move_forward,20)
#   action(train(1),move_forward,21)
#   action(train(0),move_forward,29)
#   action(train(0),move_forward,30)
#   action(train(1),move_forward,22)
#   action(train(1),move_forward,23)
#   action(train(0),move_forward,31)
#   action(train(0),move_forward,32)
#   action(train(1),move_forward,24)
#   action(train(1),move_left,25)
#   action(train(1),move_forward,26)
#   action(train(1),move_forward,27)
#   action(train(1),move_forward,28)
#   action(train(1),move_forward,29)
#   action(train(1),move_left,30)
#   action(train(1),move_forward,31)
#   action(train(1),move_left,32)
#   action(train(1),move_forward,33)
#   action(train(1),move_forward,34)
#   action(train(1),move_left,35)
#   action(train(1),move_forward,36)
#   state(0,(14,12),e,12)
#   state(1,(23,23),s,4)
#   state(1,(24,23),s,5)
#   state(0,(14,13),e,13)
#   state(0,(15,13),s,14)
#   state(1,(24,24),e,6)
#   state(1,(25,24),s,7)
#   state(0,(15,14),e,15)
#   state(0,(15,15),e,16)
#   state(1,(26,24),s,8)
#   state(1,(27,24),s,9)
#   state(0,(15,16),e,17)
#   state(0,(15,17),e,18)
#   state(1,(28,24),s,10)
#   state(1,(28,23),w,11)
#   state(0,(15,18),e,19)
#   state(0,(15,19),e,20)
#   state(1,(28,22),w,12)
#   state(1,(28,21),w,13)
#   state(0,(16,19),s,21)
#   state(0,(16,20),e,22)
#   state(1,(28,20),w,14)
#   state(1,(28,19),w,15)
#   state(0,(17,20),s,23)
#   state(0,(18,20),s,24)
#   state(1,(28,18),w,16)
#   state(1,(27,18),n,17)
#   state(0,(18,21),e,25)
#   state(0,(18,22),e,26)
#   state(1,(26,18),n,18)
#   state(1,(25,18),n,19)
#   state(0,(18,23),e,27)
#   state(0,(18,24),e,28)
#   state(1,(24,18),n,20)
#   state(1,(23,18),n,21)
#   state(0,(19,24),s,29)
#   state(0,(20,24),s,30)
#   state(1,(22,18),n,22)
#   state(1,(21,18),n,23)
#   state(0,(21,24),s,31)
#   state(0,(22,24),s,32)
#   state(1,(20,18),n,24)
#   state(1,(19,18),n,25)
#   state(0,(23,24),s,33)
#   state(1,(19,17),w,26)
#   state(1,(18,17),n,27)
#   state(1,(17,17),n,28)
#   state(1,(16,17),n,29)
#   state(1,(15,17),n,30)
#   state(1,(15,16),w,31)
#   state(1,(15,15),w,32)
#   state(1,(16,15),s,33)
#   state(1,(16,14),w,34)
#   state(1,(16,13),w,35)
#   state(1,(17,13),s,36)
#   state(1,(17,12),w,37)
#   arrived(0,33)
#   arrived(1,37)
# SAT
